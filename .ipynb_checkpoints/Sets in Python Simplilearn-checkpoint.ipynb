# %% [markdown]
# * Set is an unordered collection of unique elements
#
# * Syntax : Variable_name = set(['a','b','c','d'])

# %%
s = set([1,2,3,4])
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
s.add('Shubham')    # to add the elements in the set
print(s)
# Out:
# {1, 2, 3, 4, 'Shubham'}

# %%
fs = frozenset([1,2,3,4])   # frozen set is set in which the value of set cannot be changed 
print(fs)
# Out:
# frozenset({1, 2, 3, 4})

# %%
fs.add('Shubham')     # we cannot add the elements in the frozn set
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-45341e0b8b0e> in <module>
# ----> 1 fs.add('Shubham')     # we cannot add the elements in the frozn set
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s1 = set([1,3,7,2])
s2 = set([3,2,8,9])
print(type(s1))
print(type(s2))
# Out:
# <class 'set'>
# <class 'set'>

# %%
# Union Operation
s1.union(s2)       # Value cannot be repeaded in Sets
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
s1.difference(s2)
# Out:
# {1, 7}
